# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

file_path = "5ai1.csv" 
df = pd.read_csv(file_path)
print(df)

column1 = "Internal" 
column2 = "External" 
selected_data = df[[column1, column2]]

plt.figure(figsize=(8, 6))
plt.scatter(selected_data[column1], selected_data[column2], color="blue", alpha=0.7)
plt.title(f"Scatter Plot of {column1} vs {column2}")
plt.xlabel(column1)
plt.ylabel(column2)
plt.grid(True)
plt.show()
# Out:
#     Sl. No                   Name         USN  Internal  External  Total  \
# 0        1  ADITHYA ASHOK SAPALYA  4VP22AI001        38        20     58
# 1        2               ADYA N L  4VP22AI002        39        37     76
# 2        3             AISHWARYA   4VP22AI003        39        39     78
# 3        4       AKHILA KARUVAJE   4VP22AI004        44        40     84
# 4        5           AKSHAY KUMAR  4VP22AI005        41        39     80
# ..     ...                    ...         ...       ...       ...    ...
# 56      57           THISHUKUMAR   4VP22AI057        36        30     66
# 57      58           THRISHA RAI   4VP22AI058        38        36     74
# 58      59               THRUPTHI  4VP22AI059        43        34     77
# 59      60             UTTAM RAI   4VP22AI060        42        39     81
# 60      61           YOGYASHREE K  4VP22AI061        36        38     74
#
#         Result  Internal.1  External.1  Total.1  ... Internal.7  External.7  \
# 0   P                   95           0       95  ...         90           0
# 1   P                   98           0       98  ...        100           0
# 2   P                   96           0       96  ...         96           0
# 3   P                   99           0       99  ...        100           0
# 4   P                   95           0       95  ...         92           0
# ..         ...         ...         ...      ...  ...        ...         ...
# 56  P                   99           0       99  ...        100           0
# 57  P                   96           0       96  ...        100           0
# 58  P                   97           0       97  ...        100           0
# 59  P                   95           0       95  ...         96           0
# 60  P                   95           0       95  ...        100           0
#
#     Total.7    Result.7 Internal.8  External.8  Total.8    Result.8  \
# 0        90  P                  42          28       70  P
# 1       100  P                  44          31       75  P
# 2        96  P                  46          41       87  P
# 3       100  P                  47          35       82  P
# 4        92  P                  45          33       78  P
# ..      ...         ...        ...         ...      ...         ...
# 56      100  P                  44          29       73  P
# 57      100  P                  44          30       74  P
# 58      100  P                  45          34       79  P
# 59       96  P                  48          33       81  P
# 60      100  P                  48          26       74  P
#
#    Final Total                  Final Result
# 0          650  FIRST CLASS WITH DISTINCTION
# 1          752  FIRST CLASS WITH DISTINCTION
# 2          738  FIRST CLASS WITH DISTINCTION
# 3          788  FIRST CLASS WITH DISTINCTION
# 4          740  FIRST CLASS WITH DISTINCTION
# ..         ...                           ...
# 56         718  FIRST CLASS WITH DISTINCTION
# 57         752  FIRST CLASS WITH DISTINCTION
# 58         738  FIRST CLASS WITH DISTINCTION
# 59         771  FIRST CLASS WITH DISTINCTION
# 60         738  FIRST CLASS WITH DISTINCTION
#
# [61 rows x 41 columns]

# %%
correlation_coefficient = np.corrcoef(selected_data[column1],selected_data[column2])[0, 1]
print(f"Pearson Correlation Coefficient ({column1} vs {column2}):{correlation_coefficient}")

cov_matrix = np.cov(selected_data[column1], selected_data[column2])
print("\nCovariance Matrix:")
print(cov_matrix)

correlation_matrix = selected_data.corr()
print("\nCorrelation Matrix:")
print(correlation_matrix)

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f",
cbar=True)
plt.title("Correlation Matrix Heatmap")
plt.show()
# Out:
# Pearson Correlation Coefficient (Internal vs External):0.3974335982218998
#
# Covariance Matrix:
# [[13.33934426  6.93852459]
#  [ 6.93852459 22.84918033]]
#
# Correlation Matrix:
#           Internal  External
# Internal  1.000000  0.397434
# External  0.397434  1.000000

# %%
col3="Total"
col4="Internal"
selected_data=df[[col3,col4]]

plt.figure(figsize=(8,5))
plt.scatter(selected_data[col3],selected_data[col4],color='blue',alpha=0.8)
plt.title(f' scatter plot of {col3} vs {col4}')
plt.xlabel(col3)
plt.ylabel(col4)
plt.grid(True)
plt.show()

# %%
cor_coef=np.corrcoef(selected_data[col3],selected_data[col4])[0,1]
print(f'Pearson correlation coefficient ({col3} vs {col4}): {cor_coef}')

cova_matrix = np.cov(selected_data[col3], selected_data[col4])
print("\nCovariance Matrix:")
print(cova_matrix)

correlation_matrix = selected_data.corr()
print("\nCorrelation matrix:")
print(correlation_matrix)


plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f",
cbar=True)
plt.title("Correlation Matrix Heatmap")
plt.show()
# Out:
# Pearson correlation coefficient (Total vs Internal): 0.7846671486821536
#
# Covariance Matrix:
# [[50.06557377 20.27786885]
#  [20.27786885 13.33934426]]
#
# Correlation matrix:
#              Total  Internal
# Total     1.000000  0.784667
# Internal  0.784667  1.000000
