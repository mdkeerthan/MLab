# %%
# !pip install openpyxl
# !pip install xlrd
# Out:
# ...
#    ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
# ...

# %%
import pandas as pd
import numpy as np

df = pd.read_excel("Sem_Marks.xls", engine = "xlrd", header = [0,1])
print(df.columns)

df_tc = df["TC"]
int_marks =df[("TC", "Internal")]
ext_marks =df[("TC", "External")]

selected_data = df[int_marks, ext_marks]

corr_coef = np.corrcoef(selected_data[int_marks],selected_data[ext_marks])[0,1]
print(corr_coef)
# Out:
# MultiIndex([(                                      'Unnamed: 0_level_0', ...),
#             (                                      'Unnamed: 1_level_0', ...),
#             (                                      'Unnamed: 2_level_0', ...),
#             (                       'INFORMATION RETRIEVAL(BAI515B   )', ...),
#             (                       'INFORMATION RETRIEVAL(BAI515B   )', ...),
#             (                       'INFORMATION RETRIEVAL(BAI515B   )', ...),
#             (                       'INFORMATION RETRIEVAL(BAI515B   )', ...),
#             (                                'MINI PROJECT(BAI586    )', ...),
#             (                                'MINI PROJECT(BAI586    )', ...),
#             (                                'MINI PROJECT(BAI586    )', ...),
#             (                                'MINI PROJECT(BAI586    )', ...),
#             (                      'DATA VISUALIZATION LAB(BAIL504   )', ...),
# ...
